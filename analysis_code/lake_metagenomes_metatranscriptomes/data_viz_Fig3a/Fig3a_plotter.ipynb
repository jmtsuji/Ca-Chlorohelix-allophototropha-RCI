# %%
# Make RNA genome plot
# Jackson M. Tsuji, 2021
# Used for Figure 3b of the Chlorohelix publication

# %%
import pandas as pd
from plotnine import *

# %%
# Variables
mag_table_filepath = 'input_data/MAG_table_RNA_to_unassembled.tsv' # Copied from lake_metatranscriptomes/summary
metadata_filepath = 'input_data/sample_metadata.tsv'

# For parsing MAG tables
taxonomy_headers = ['Domain', 'Phylum', 'Class', 'Order', 'Family', 'Genus', 'Species']
checkm_headers = ['Completeness', 'Contamination', 'Strain_heterogeneity']
mag_table_headers = ['MAG_ID'] + taxonomy_headers + checkm_headers

# %%
# Read metadata
metadata = pd.read_csv(metadata_filepath, sep='\t')
metadata.head()
# Out:
#                rep-id         sample-id   plot-id
# 0  Jun2018_L221_05m_A  Jun2018_L221_05m  Lake 221
# 1  Jun2018_L221_05m_B  Jun2018_L221_05m  Lake 221
# 2  Jun2018_L221_05m_C  Jun2018_L221_05m  Lake 221
# 3  Jun2018_L304_06m_A  Jun2018_L304_06m  Lake 304
# 4  Jun2018_L304_06m_B  Jun2018_L304_06m  Lake 304

# %%
# Read MAG table and only keep samples specified in metadata
mag_table = pd.read_csv(mag_table_filepath, sep='\t')\
  [mag_table_headers+metadata['rep-id'].to_list()]
mag_table.head()
# Out:
#    MAG_ID   Domain         Phylum            Class               Order  \
# 0  MAG229  Archaea  Halobacterota           Bog-38              Bog-38
# 1  MAG045  Archaea  Halobacterota  Methanomicrobia  Methanomicrobiales
# 2  MAG211  Archaea  Halobacterota  Methanomicrobia  Methanomicrobiales
# 3  MAG346  Archaea  Halobacterota  Methanomicrobia  Methanomicrobiales
# 4  MAG380  Archaea  Halobacterota  Methanomicrobia  Methanomicrobiales
#
#               Family                         Genus  \
# 0             Bog-38                        Bog-38
# 1  Methanoregulaceae                 Methanoregula
# 2  Methanoregulaceae                 Methanoregula
# 3  Methanoregulaceae                 Methanoregula
# 4  Methanoregulaceae  Unresolved_Methanoregulaceae
#
#                         Species  Completeness  Contamination  \
# 0             Unresolved_Bog-38         90.31           1.31
# 1      Unresolved_Methanoregula         66.29           1.96
# 2      Unresolved_Methanoregula         89.14           1.33
# 3      Unresolved_Methanoregula         85.89           0.65
# 4  Unresolved_Methanoregulaceae         95.75           1.96
#
#    Strain_heterogeneity  Jun2018_L221_05m_A  Jun2018_L221_05m_B  \
# 0                  0.00            0.000195            0.000196
# 1                  0.00            0.000586            0.000470
# 2                 66.67            0.001540            0.000916
# 3                100.00            0.002242            0.002231
# 4                 25.00            0.000940            0.000728
#
#    Jun2018_L221_05m_C  Jun2018_L304_06m_A  Jun2018_L304_06m_B  \
# 0            0.000240            0.000165            0.000064
# 1            0.000527            0.000841            0.001161
# 2            0.001417            0.000841            0.001054
# 3            0.002563            0.004143            0.005060
# 4            0.000674            0.000094            0.000099
#
#    Jun2018_L304_06m_C
# 0            0.000105
# 1            0.000949
# 2            0.000979
# 3            0.004986
# 4            0.000149

# %%
# First get the proportion of mapped reads for reference
total_mapped_reads = pd.DataFrame(mag_table.set_index(mag_table_headers).sum())\
  .reset_index()\

total_mapped_reads.columns = ['rep-id', 'Mapped RNA reads (%)']

total_mapped_reads.head()
# Out:
#                rep-id  Mapped RNA reads (%)
# 0  Jun2018_L221_05m_A             24.749077
# 1  Jun2018_L221_05m_B             25.364008
# 2  Jun2018_L221_05m_C             24.328850
# 3  Jun2018_L304_06m_A             26.645483
# 4  Jun2018_L304_06m_B             26.168771

# %%
# Do some stats on the proportion of mapped reads, for reference
total_mapped_reads_summary = total_mapped_reads.merge(metadata[['rep-id', 'plot-id']])\
  .drop(columns=['rep-id'])\
  .groupby('plot-id')\
  .agg({'Mapped RNA reads (%)':['mean', 'std']})\
  .reset_index()

total_mapped_reads_summary.columns = ['_'.join(column).rstrip('_') for column in total_mapped_reads_summary.columns.to_flat_index()]

total_mapped_reads_summary.head()
# Out:
#     plot-id  Mapped RNA reads (%)_mean  Mapped RNA reads (%)_std
# 0  Lake 221                  24.813978                  0.520622
# 1  Lake 304                  26.625006                  0.446348

# %%
# Re-normalize relative abundances within MAG set
mag_table_norm = mag_table.set_index(mag_table_headers)

mag_table_norm = mag_table_norm.div(mag_table_norm.sum(), axis=1) * 100

mag_table_norm.head()
# Out:
#                                                                                                                                                                                              Jun2018_L221_05m_A  \
# MAG_ID Domain  Phylum        Class           Order              Family            Genus                        Species                      Completeness Contamination Strain_heterogeneity
# MAG229 Archaea Halobacterota Bog-38          Bog-38             Bog-38            Bog-38                       Unresolved_Bog-38            90.31        1.31          0.00                            0.000789
# MAG045 Archaea Halobacterota Methanomicrobia Methanomicrobiales Methanoregulaceae Methanoregula                Unresolved_Methanoregula     66.29        1.96          0.00                            0.002367
# MAG211 Archaea Halobacterota Methanomicrobia Methanomicrobiales Methanoregulaceae Methanoregula                Unresolved_Methanoregula     89.14        1.33          66.67                           0.006224
# MAG346 Archaea Halobacterota Methanomicrobia Methanomicrobiales Methanoregulaceae Methanoregula                Unresolved_Methanoregula     85.89        0.65          100.00                          0.009058
# MAG380 Archaea Halobacterota Methanomicrobia Methanomicrobiales Methanoregulaceae Unresolved_Methanoregulaceae Unresolved_Methanoregulaceae 95.75        1.96          25.00                           0.003798
#
#                                                                                                                                                                                              Jun2018_L221_05m_B  \
# MAG_ID Domain  Phylum        Class           Order              Family            Genus                        Species                      Completeness Contamination Strain_heterogeneity
# MAG229 Archaea Halobacterota Bog-38          Bog-38             Bog-38            Bog-38                       Unresolved_Bog-38            90.31        1.31          0.00                            0.000772
# MAG045 Archaea Halobacterota Methanomicrobia Methanomicrobiales Methanoregulaceae Methanoregula                Unresolved_Methanoregula     66.29        1.96          0.00                            0.001852
# MAG211 Archaea Halobacterota Methanomicrobia Methanomicrobiales Methanoregulaceae Methanoregula                Unresolved_Methanoregula     89.14        1.33          66.67                           0.003611
# MAG346 Archaea Halobacterota Methanomicrobia Methanomicrobiales Methanoregulaceae Methanoregula                Unresolved_Methanoregula     85.89        0.65          100.00                          0.008796
# MAG380 Archaea Halobacterota Methanomicrobia Methanomicrobiales Methanoregulaceae Unresolved_Methanoregulaceae Unresolved_Methanoregulaceae 95.75        1.96          25.00                           0.002870
#
#                                                                                                                                                                                              Jun2018_L221_05m_C  \
# MAG_ID Domain  Phylum        Class           Order              Family            Genus                        Species                      Completeness Contamination Strain_heterogeneity
# MAG229 Archaea Halobacterota Bog-38          Bog-38             Bog-38            Bog-38                       Unresolved_Bog-38            90.31        1.31          0.00                            0.000987
# MAG045 Archaea Halobacterota Methanomicrobia Methanomicrobiales Methanoregulaceae Methanoregula                Unresolved_Methanoregula     66.29        1.96          0.00                            0.002165
# MAG211 Archaea Halobacterota Methanomicrobia Methanomicrobiales Methanoregulaceae Methanoregula                Unresolved_Methanoregula     89.14        1.33          66.67                           0.005825
# MAG346 Archaea Halobacterota Methanomicrobia Methanomicrobiales Methanoregulaceae Methanoregula                Unresolved_Methanoregula     85.89        0.65          100.00                          0.010537
# MAG380 Archaea Halobacterota Methanomicrobia Methanomicrobiales Methanoregulaceae Unresolved_Methanoregulaceae Unresolved_Methanoregulaceae 95.75        1.96          25.00                           0.002769
#
#                                                                                                                                                                                              Jun2018_L304_06m_A  \
# MAG_ID Domain  Phylum        Class           Order              Family            Genus                        Species                      Completeness Contamination Strain_heterogeneity
# MAG229 Archaea Halobacterota Bog-38          Bog-38             Bog-38            Bog-38                       Unresolved_Bog-38            90.31        1.31          0.00                            0.000620
# MAG045 Archaea Halobacterota Methanomicrobia Methanomicrobiales Methanoregulaceae Methanoregula                Unresolved_Methanoregula     66.29        1.96          0.00                            0.003157
# MAG211 Archaea Halobacterota Methanomicrobia Methanomicrobiales Methanoregulaceae Methanoregula                Unresolved_Methanoregula     89.14        1.33          66.67                           0.003157
# MAG346 Archaea Halobacterota Methanomicrobia Methanomicrobiales Methanoregulaceae Methanoregula                Unresolved_Methanoregula     85.89        0.65          100.00                          0.015548
# MAG380 Archaea Halobacterota Methanomicrobia Methanomicrobiales Methanoregulaceae Unresolved_Methanoregulaceae Unresolved_Methanoregulaceae 95.75        1.96          25.00                           0.000354
#
#                                                                                                                                                                                              Jun2018_L304_06m_B  \
# MAG_ID Domain  Phylum        Class           Order              Family            Genus                        Species                      Completeness Contamination Strain_heterogeneity
# MAG229 Archaea Halobacterota Bog-38          Bog-38             Bog-38            Bog-38                       Unresolved_Bog-38            90.31        1.31          0.00                            0.000243
# MAG045 Archaea Halobacterota Methanomicrobia Methanomicrobiales Methanoregulaceae Methanoregula                Unresolved_Methanoregula     66.29        1.96          0.00                            0.004435
# MAG211 Archaea Halobacterota Methanomicrobia Methanomicrobiales Methanoregulaceae Methanoregula                Unresolved_Methanoregula     89.14        1.33          66.67                           0.004029
# MAG346 Archaea Halobacterota Methanomicrobia Methanomicrobiales Methanoregulaceae Methanoregula                Unresolved_Methanoregula     85.89        0.65          100.00                          0.019336
# MAG380 Archaea Halobacterota Methanomicrobia Methanomicrobiales Methanoregulaceae Unresolved_Methanoregulaceae Unresolved_Methanoregulaceae 95.75        1.96          25.00                           0.000379
#
#                                                                                                                                                                                              Jun2018_L304_06m_C
# MAG_ID Domain  Phylum        Class           Order              Family            Genus                        Species                      Completeness Contamination Strain_heterogeneity
# MAG229 Archaea Halobacterota Bog-38          Bog-38             Bog-38            Bog-38                       Unresolved_Bog-38            90.31        1.31          0.00                            0.000387
# MAG045 Archaea Halobacterota Methanomicrobia Methanomicrobiales Methanoregulaceae Methanoregula                Unresolved_Methanoregula     66.29        1.96          0.00                            0.003508
# MAG211 Archaea Halobacterota Methanomicrobia Methanomicrobiales Methanoregulaceae Methanoregula                Unresolved_Methanoregula     89.14        1.33          66.67                           0.003619
# MAG346 Archaea Halobacterota Methanomicrobia Methanomicrobiales Methanoregulaceae Methanoregula                Unresolved_Methanoregula     85.89        0.65          100.00                          0.018424
# MAG380 Archaea Halobacterota Methanomicrobia Methanomicrobiales Methanoregulaceae Unresolved_Methanoregulaceae Unresolved_Methanoregulaceae 95.75        1.96          25.00                           0.000552

# %%
# Make long version
mag_table_long = mag_table_norm.reset_index()\
  .melt(id_vars=mag_table_headers, var_name='rep-id', value_name='Relative abundance (%)')\
  .merge(metadata[['rep-id', 'plot-id']], on='rep-id', how='left')\
  .drop(columns=['rep-id'])

mag_table_long.head()
# Out:
#    MAG_ID   Domain         Phylum            Class               Order  \
# 0  MAG229  Archaea  Halobacterota           Bog-38              Bog-38
# 1  MAG045  Archaea  Halobacterota  Methanomicrobia  Methanomicrobiales
# 2  MAG211  Archaea  Halobacterota  Methanomicrobia  Methanomicrobiales
# 3  MAG346  Archaea  Halobacterota  Methanomicrobia  Methanomicrobiales
# 4  MAG380  Archaea  Halobacterota  Methanomicrobia  Methanomicrobiales
#
#               Family                         Genus  \
# 0             Bog-38                        Bog-38
# 1  Methanoregulaceae                 Methanoregula
# 2  Methanoregulaceae                 Methanoregula
# 3  Methanoregulaceae                 Methanoregula
# 4  Methanoregulaceae  Unresolved_Methanoregulaceae
#
#                         Species  Completeness  Contamination  \
# 0             Unresolved_Bog-38         90.31           1.31
# 1      Unresolved_Methanoregula         66.29           1.96
# 2      Unresolved_Methanoregula         89.14           1.33
# 3      Unresolved_Methanoregula         85.89           0.65
# 4  Unresolved_Methanoregulaceae         95.75           1.96
#
#    Strain_heterogeneity  Relative abundance (%)   plot-id
# 0                  0.00                0.000789  Lake 221
# 1                  0.00                0.002367  Lake 221
# 2                 66.67                0.006224  Lake 221
# 3                100.00                0.009058  Lake 221
# 4                 25.00                0.003798  Lake 221

# %%
# Summarize stats
mag_table_summary = mag_table_long.groupby(mag_table_headers + ['plot-id'])\
  .agg({'Relative abundance (%)':['mean', 'std']})\
  .reset_index()

mag_table_summary.columns = ['_'.join(column).rstrip('_') for column in mag_table_summary.columns.to_flat_index()]

mag_table_summary.head()
# Out:
#    MAG_ID    Domain               Phylum             Class  \
# 0  MAG001  Bacteria    Verrucomicrobiota  Verrucomicrobiae
# 1  MAG001  Bacteria    Verrucomicrobiota  Verrucomicrobiae
# 2  MAG002  Bacteria      Planctomycetota    Planctomycetes
# 3  MAG002  Bacteria      Planctomycetota    Planctomycetes
# 4  MAG003  Bacteria  Verrucomicrobiota_A        Chlamydiia
#
#                 Order             Family                         Genus  \
# 0  Chthoniobacterales  Terrimicrobiaceae  Unresolved_Terrimicrobiaceae
# 1  Chthoniobacterales  Terrimicrobiaceae  Unresolved_Terrimicrobiaceae
# 2        Pirellulales            UBA1268                  BAIKAL-G1-2R
# 3        Pirellulales            UBA1268                  BAIKAL-G1-2R
# 4    Parachlamydiales  Parachlamydiaceae  Unresolved_Parachlamydiaceae
#
#                         Species  Completeness  Contamination  \
# 0  Unresolved_Terrimicrobiaceae         85.41           2.03
# 1  Unresolved_Terrimicrobiaceae         85.41           2.03
# 2       Unresolved_BAIKAL-G1-2R         96.55           2.30
# 3       Unresolved_BAIKAL-G1-2R         96.55           2.30
# 4  Unresolved_Parachlamydiaceae         94.03           2.36
#
#    Strain_heterogeneity   plot-id  Relative abundance (%)_mean  \
# 0                   0.0  Lake 221                     0.015207
# 1                   0.0  Lake 304                     0.027510
# 2                   0.0  Lake 221                     0.008841
# 3                   0.0  Lake 304                     0.013108
# 4                   0.0  Lake 221                     0.002669
#
#    Relative abundance (%)_std
# 0                    0.001128
# 1                    0.003213
# 2                    0.001830
# 3                    0.001418
# 4                    0.000118

# %%
# Final plotting prep
# Filter to those over 1%
plotting_data = mag_table_summary.copy(deep=True)[mag_table_summary['Relative abundance (%)_mean'] > 1]

# Add percent label
plotting_data['percent_label'] = plotting_data['Relative abundance (%)_mean'].round(decimals=1)

# Add genome label
plotting_data['genome_label'] = plotting_data['Genus'] + ' bin ELA' + plotting_data['MAG_ID'].str.split('MAG',expand=True)[1] + \
  ' (' + plotting_data['Completeness'].round(decimals=1).apply(str) + '/' + plotting_data['Contamination'].round(decimals=1).apply(str) + ')'

# Add genome order
plotting_data = plotting_data.sort_values(by=taxonomy_headers + ['MAG_ID'], ascending=False)
plotting_data['genome_label'] = pd.Categorical(plotting_data['genome_label'], categories=plotting_data['genome_label'].unique(), ordered=True)

plotting_data.head()
# Out:
#       MAG_ID    Domain             Phylum                Class  \
# 671   MAG361  Bacteria  Verrucomicrobiota     Verrucomicrobiae
# 449   MAG239  Bacteria     Proteobacteria  Gammaproteobacteria
# 969   MAG530  Bacteria     Proteobacteria  Gammaproteobacteria
# 1128  MAG616  Bacteria     Proteobacteria  Gammaproteobacteria
# 184   MAG097  Bacteria     Proteobacteria  Gammaproteobacteria
#
#                 Order             Family         Genus  \
# 671    Pedosphaerales    Pedosphaeraceae      UBA11358
# 449   Methylococcales  Methylomonadaceae      UBA10906
# 969   Methylococcales  Methylomonadaceae          KS41
# 1128  Methylococcales   Methylococcaceae       UBA6136
# 184   Burkholderiales     Rhodocyclaceae  Sulfuritalea
#
#                       Species  Completeness  Contamination  \
# 671       Unresolved_UBA11358         91.33           3.76
# 449       Unresolved_UBA10906         94.52           0.92
# 969           Unresolved_KS41         96.42           1.38
# 1128       Unresolved_UBA6136         96.90           0.78
# 184   Unresolved_Sulfuritalea         96.54           0.44
#
#       Strain_heterogeneity   plot-id  Relative abundance (%)_mean  \
# 671                   37.5  Lake 304                     1.423638
# 449                   40.0  Lake 304                     7.592239
# 969                   20.0  Lake 304                     1.117790
# 1128                   0.0  Lake 221                     2.748633
# 184                    0.0  Lake 221                     1.285957
#
#       Relative abundance (%)_std  percent_label  \
# 671                     0.136308            1.4
# 449                     0.287079            7.6
# 969                     0.054975            1.1
# 1128                    0.289827            2.7
# 184                     0.127924            1.3
#
#                             genome_label
# 671       UBA11358 bin ELA361 (91.3/3.8)
# 449       UBA10906 bin ELA239 (94.5/0.9)
# 969           KS41 bin ELA530 (96.4/1.4)
# 1128       UBA6136 bin ELA616 (96.9/0.8)
# 184   Sulfuritalea bin ELA097 (96.5/0.4)

# %%
# Plot
fig3a_plot = (ggplot(plotting_data, aes(x = 'plot-id', y='genome_label'))
            + geom_point(aes(size='Relative abundance (%)_mean', fill='Phylum'), alpha=0.7)
            + geom_text(aes(label='percent_label'), size=4)
            + theme_bw()
            + theme(text=element_text(family='Arial', colour='black'),
                    line=element_line(colour='black'),
                    panel_border=element_rect(colour='black'),
                    panel_grid=element_line(colour='#cccccc'),
                    legend_key=element_blank(),
                    legend_margin=0,
                    legend_text=element_text(face='italic'),
                   axis_text_y=element_text(size=8))
            + scale_size_continuous(range=[3,30])
            + guides(size=False, fill=guide_legend(override_aes={'size':6}))
            + scale_fill_brewer(type='qualitative', palette=2)
            + ylab('Genome bin')
            + xlab('Lake'))

print(fig3a_plot)
# Out:
# /Analysis/jmtsuji/miniconda3_mellea/envs/jupyterlab/lib/python3.7/site-packages/plotnine/utils.py:1246: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
# <ggplot: (-9223363255813206577)>

# %%
fig3a_plot.save('Figure_3a_raw.pdf', width=50, height=130, units='mm')
# Out:
# /Analysis/jmtsuji/miniconda3_mellea/envs/jupyterlab/lib/python3.7/site-packages/plotnine/ggplot.py:729: PlotnineWarning: Saving 50.0 x 130.00000000000003 mm image.
# /Analysis/jmtsuji/miniconda3_mellea/envs/jupyterlab/lib/python3.7/site-packages/plotnine/ggplot.py:730: PlotnineWarning: Filename: Figure_3a_raw.pdf
# /Analysis/jmtsuji/miniconda3_mellea/envs/jupyterlab/lib/python3.7/site-packages/plotnine/utils.py:1246: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
